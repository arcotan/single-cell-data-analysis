# %% [markdown]
# # Clustering and differential expression analysis of PBMC2 using scVI-tools

# %%
import matplotlib.pyplot as plt
import scanpy as sc
import pandas as pd
import numpy as np
import anndata
import scvi
import os

# %%
num_of_clusters = 16 # should be 16 for PBMC2

tool_name = 'scvi-tools'
dataset_name = 'PBMC2'
data_path = '../../dataset/{}-Filtered/10x/'.format(dataset_name)
save_path = '../../results/{}/{}/'.format(dataset_name, tool_name)

if not os.path.exists(save_path):
    os.makedirs(save_path)

# %% [markdown]
# ## Data loading and preparation

# %% [markdown]
# Dataset loading

# %%
adata = sc.read_10x_mtx(
    data_path,
    var_names='gene_symbols',
    cache=False
)
adata.var_names_make_unique()
adata
# Out:
# AnnData object with n_obs × n_vars = 6019 × 13707
#     var: 'gene_ids'

# %% [markdown]
# Studying feature variance

# %%
matrix = adata.X
matrix = matrix.todense()
neg_variances = np.sort(-np.var(matrix, axis=0))
sorted_log_variances = [np.log(-i) for i in neg_variances.T][:2000]
plt.scatter([i for i in range(len(sorted_log_variances))], sorted_log_variances)

# %% [markdown]
# Data normalization

# %%
adata.layers["counts"] = adata.X.copy()
sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)
adata.raw = adata

# %% [markdown]
# Feature selection

# %%
sc.pp.highly_variable_genes(
    adata,
    n_top_genes=400, # chosen based on elbow plot above
    subset=True,
    layer="counts",
    flavor="seurat_v3",
)
sc.pl.highly_variable_genes(adata)

# %%
#sc.pp.scale(adata, max_value=10) # FIXME: not done in scivi-tools tutorial, done in scanpy

# %% [markdown]
# ## Model training

# %%
import os

os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

scvi.model.SCVI.setup_anndata(
    adata,
    layer="counts", # FIXME: need to specify other params?
    n_latent=
)

model = scvi.model.SCVI(adata)
model.train(use_gpu=False)
model.save('./models/{}/'.format(dataset_name), overwrite=True)

model
# Out:
# /home/matteo/miniconda3/envs/cotan/lib/python3.11/site-packages/scvi/data/fields/_layer_field.py:101: UserWarning: Training will be faster when sparse matrix is formatted as CSR. It is safe to cast before model initialization.
#   _verify_and_correct_data_format(adata, self.attr_name, self.attr_key)
# /home/matteo/miniconda3/envs/cotan/lib/python3.11/site-packages/scvi/train/_trainrunner.py:76: UserWarning: `use_gpu` is deprecated in v1.0 and will be removed in v1.1. Please use `accelerator` and `devices` instead.
#   accelerator, lightning_devices, device = parse_device_args(
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Epoch 1/400:   0%|          | 0/400 [00:00<?, ?it/s]
# Epoch 400/400: 100%|██████████| 400/400 [03:05<00:00,  2.15it/s, v_num=1, train_loss_step=149, train_loss_epoch=143]
# `Trainer.fit` stopped: `max_epochs=400` reached.
# Epoch 400/400: 100%|██████████| 400/400 [03:05<00:00,  2.15it/s, v_num=1, train_loss_step=149, train_loss_epoch=143]
# SCVI Model with the following params:
# n_hidden: 128, n_latent: 10, n_layers: 1, dropout_rate: 0.1, dispersion: gene, gene_likelihood: zinb,
# latent_distribution: normal
# Training status: Trained
# Model's adata is minified?: False

# %% [markdown]
# ## Clustering

# %% [markdown]
# Save latent representation

# %%
latent = model.get_latent_representation()
adata.obsm["X_scVI"] = latent
adata.layers["scvi_normalized"] = model.get_normalized_expression() # FIXME: really needed?

# %% [markdown]
# Plot pca explained variance ratio to choose number of components

# %%
sc.tl.pca(adata, svd_solver="arpack", n_comps=100, use_highly_variable=True)
sc.pl.pca_variance_ratio(adata, log=True)

# %% [markdown]
# Perform the clustering

# %%
sc.pp.neighbors(
    adata,
    # n_pcs=11, # chosen based on elbow plot above
    #n_neighbors=20, # FIXME: how to choose this? default is 15, 20 in the tutorial (heart cell atlas)
                    # it is the number of nearest neighbors to be searched
                    # "Larger values result in more global views of the manifold,
                    #  while smaller values result in more local data being preserved"
    use_rep="X_scVI"
)
res = 0.000
sc.tl.leiden(adata, key_added="leiden_scVI", resolution=res)
while not (adata.obs.leiden_scVI.values.categories.values).shape == (num_of_clusters,):
    print(f"Clustering with resolution={res}...")
    res += 0.005
    sc.tl.leiden(adata, key_added="leiden_scVI", resolution=res)
# Out:
# Clustering with resolution=0.0...
# Clustering with resolution=0.005...
# Clustering with resolution=0.01...
# Clustering with resolution=0.015...
# Clustering with resolution=0.02...
# Clustering with resolution=0.025...
# Clustering with resolution=0.030000000000000002...
# Clustering with resolution=0.035...
# Clustering with resolution=0.04...
# Clustering with resolution=0.045...
# Clustering with resolution=0.049999999999999996...
# Clustering with resolution=0.05499999999999999...
# Clustering with resolution=0.05999999999999999...
# Clustering with resolution=0.06499999999999999...
# Clustering with resolution=0.06999999999999999...
# Clustering with resolution=0.075...
# Clustering with resolution=0.08...
# Clustering with resolution=0.085...
# Clustering with resolution=0.09000000000000001...
# Clustering with resolution=0.09500000000000001...
# Clustering with resolution=0.10000000000000002...
# Clustering with resolution=0.10500000000000002...
# Clustering with resolution=0.11000000000000003...
# Clustering with resolution=0.11500000000000003...
# Clustering with resolution=0.12000000000000004...
# Clustering with resolution=0.12500000000000003...
# Clustering with resolution=0.13000000000000003...
# Clustering with resolution=0.13500000000000004...
# Clustering with resolution=0.14000000000000004...
# Clustering with resolution=0.14500000000000005...
# Clustering with resolution=0.15000000000000005...
# Clustering with resolution=0.15500000000000005...
# Clustering with resolution=0.16000000000000006...
# Clustering with resolution=0.16500000000000006...
# Clustering with resolution=0.17000000000000007...
# Clustering with resolution=0.17500000000000007...
# Clustering with resolution=0.18000000000000008...
# Clustering with resolution=0.18500000000000008...
# Clustering with resolution=0.19000000000000009...
# Clustering with resolution=0.1950000000000001...
# Clustering with resolution=0.2000000000000001...
# Clustering with resolution=0.2050000000000001...
# Clustering with resolution=0.2100000000000001...
# Clustering with resolution=0.2150000000000001...
# Clustering with resolution=0.2200000000000001...
# Clustering with resolution=0.22500000000000012...
# Clustering with resolution=0.23000000000000012...
# Clustering with resolution=0.23500000000000013...
# Clustering with resolution=0.24000000000000013...
# Clustering with resolution=0.24500000000000013...
# Clustering with resolution=0.2500000000000001...
# Clustering with resolution=0.2550000000000001...
# Clustering with resolution=0.2600000000000001...
# Clustering with resolution=0.2650000000000001...
# Clustering with resolution=0.27000000000000013...
# Clustering with resolution=0.27500000000000013...
# Clustering with resolution=0.28000000000000014...
# Clustering with resolution=0.28500000000000014...
# Clustering with resolution=0.29000000000000015...
# Clustering with resolution=0.29500000000000015...
# Clustering with resolution=0.30000000000000016...
# Clustering with resolution=0.30500000000000016...
# Clustering with resolution=0.31000000000000016...
# Clustering with resolution=0.31500000000000017...
# Clustering with resolution=0.3200000000000002...
# Clustering with resolution=0.3250000000000002...
# Clustering with resolution=0.3300000000000002...
# Clustering with resolution=0.3350000000000002...
# Clustering with resolution=0.3400000000000002...
# Clustering with resolution=0.3450000000000002...
# Clustering with resolution=0.3500000000000002...
# Clustering with resolution=0.3550000000000002...
# Clustering with resolution=0.3600000000000002...
# Clustering with resolution=0.3650000000000002...
# Clustering with resolution=0.3700000000000002...
# Clustering with resolution=0.3750000000000002...
# Clustering with resolution=0.3800000000000002...
# Clustering with resolution=0.38500000000000023...
# Clustering with resolution=0.39000000000000024...
# Clustering with resolution=0.39500000000000024...
# Clustering with resolution=0.40000000000000024...
# Clustering with resolution=0.40500000000000025...
# Clustering with resolution=0.41000000000000025...
# Clustering with resolution=0.41500000000000026...
# Clustering with resolution=0.42000000000000026...
# Clustering with resolution=0.42500000000000027...
# Clustering with resolution=0.43000000000000027...
# Clustering with resolution=0.4350000000000003...
# Clustering with resolution=0.4400000000000003...
# Clustering with resolution=0.4450000000000003...
# Clustering with resolution=0.4500000000000003...
# Clustering with resolution=0.4550000000000003...
# Clustering with resolution=0.4600000000000003...
# Clustering with resolution=0.4650000000000003...
# Clustering with resolution=0.4700000000000003...
# Clustering with resolution=0.4750000000000003...
# Clustering with resolution=0.4800000000000003...
# Clustering with resolution=0.4850000000000003...
# Clustering with resolution=0.4900000000000003...
# Clustering with resolution=0.49500000000000033...
# Clustering with resolution=0.5000000000000003...
# Clustering with resolution=0.5050000000000003...
# Clustering with resolution=0.5100000000000003...
# Clustering with resolution=0.5150000000000003...
# Clustering with resolution=0.5200000000000004...
# Clustering with resolution=0.5250000000000004...
# Clustering with resolution=0.5300000000000004...
# Clustering with resolution=0.5350000000000004...
# Clustering with resolution=0.5400000000000004...
# Clustering with resolution=0.5450000000000004...
# Clustering with resolution=0.5500000000000004...
# Clustering with resolution=0.5550000000000004...
# Clustering with resolution=0.5600000000000004...
# Clustering with resolution=0.5650000000000004...
# Clustering with resolution=0.5700000000000004...
# Clustering with resolution=0.5750000000000004...
# Clustering with resolution=0.5800000000000004...
# Clustering with resolution=0.5850000000000004...
# Clustering with resolution=0.5900000000000004...
# Clustering with resolution=0.5950000000000004...
# Clustering with resolution=0.6000000000000004...
# Clustering with resolution=0.6050000000000004...
# Clustering with resolution=0.6100000000000004...
# Clustering with resolution=0.6150000000000004...
# Clustering with resolution=0.6200000000000004...
# Clustering with resolution=0.6250000000000004...
# Clustering with resolution=0.6300000000000004...
# Clustering with resolution=0.6350000000000005...
# Clustering with resolution=0.6400000000000005...
# Clustering with resolution=0.6450000000000005...
# Clustering with resolution=0.6500000000000005...
# Clustering with resolution=0.6550000000000005...
# Clustering with resolution=0.6600000000000005...
# Clustering with resolution=0.6650000000000005...
# Clustering with resolution=0.6700000000000005...
# Clustering with resolution=0.6750000000000005...
# Clustering with resolution=0.6800000000000005...
# Clustering with resolution=0.6850000000000005...
# Clustering with resolution=0.6900000000000005...
# Clustering with resolution=0.6950000000000005...
# Clustering with resolution=0.7000000000000005...
# Clustering with resolution=0.7050000000000005...
# Clustering with resolution=0.7100000000000005...

# %% [markdown]
# Visualize the clustering in the PCA space

# %%
sc.pl.pca(
    adata,
    color=["leiden_scVI"],
    size=20,
)
# Out:
# /home/matteo/miniconda3/envs/cotan/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:1251: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# /home/matteo/miniconda3/envs/cotan/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %% [markdown]
# Save the clustering results

# %%
df = pd.DataFrame(adata.obs['leiden_scVI'])
labels = df.rename(columns={'leiden_scVI': 'cluster'})
labels.index.names = ['cell']
labels['cluster'] = labels['cluster'].astype(int) + 1
labels.to_csv(save_path+'clustering_labels.csv')

# %% [markdown]
# ## Differential expression

# %%
# sc.tl.rank_genes_groups(adata, 'leiden_scVI', method='wilcoxon') # FIXME: really needed?

# %% [markdown]
# Perform the differential expression analysis

# %%
de_df = model.differential_expression(
    groupby="leiden_scVI",
)
# Out:
# DE...: 100%|██████████| 16/16 [00:04<00:00,  3.62it/s]

# %% [markdown]
# Save markers

# %%
number_of_markers = 400
markers = {}
cats = adata.obs.leiden_scVI.cat.categories
for i, c in enumerate(cats):
    cell_type_df = de_df.loc[de_df.group1 == c]
    #cell_type_df = cell_type_df[cell_type_df.lfc_mean > 0] # FIXME: was missing, done in the tutorial but does not seem necessary
    # cell_type_df = cell_type_df[cell_type_df["bayes_factor"] > 0] # FIXME: set to 3 in the tutorial, if 1 there are not enough markers
    #cell_type_df = cell_type_df[cell_type_df["non_zeros_proportion1"] > 0.1] # FIXME: there are not enough markers
    markers[c] = cell_type_df.sort_values('lfc_mean', ascending=False).index.tolist()[:number_of_markers]

df = pd.DataFrame(columns=['gene', 'cluster', 'rank'])
for i in range(num_of_clusters):
    to_add = [ [markers[str(i)][j], i, j] for j in range(number_of_markers)]
    to_add = pd.DataFrame(to_add, columns=['gene', 'cluster', 'rank'])
    df = pd.concat([df, to_add],  ignore_index=True)

df['cluster'] += 1
df['rank'] += 1
df.to_csv(save_path+'markers.csv', index=False)
