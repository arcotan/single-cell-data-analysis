# %%
import numpy as np
import pandas as pd
import scanpy as sc
import os
import matplotlib.pyplot as plt



num_of_clusters = 11

ToolName = 'scanpy' 
DatasetName = 'peripheral-blood'
Data_path = '../../dataset/{}-filtered/10X/'.format(DatasetName)
save_path = '../../results/{}/{}/'.format(DatasetName, ToolName)

if not os.path.exists(save_path):
    os.makedirs(save_path)


# for white background of figures (only for docs rendering)
# %config InlineBackend.print_figure_kwargs={'facecolor' : "w"}
# %config InlineBackend.figure_format='retina'

# %%
adata = sc.read_10x_mtx(
    Data_path,  # the directory with the `.mtx` file
    var_names='gene_symbols',                # use gene symbols for the variable names (variables-axis index)
    cache=False
)

# %%
matrix = adata.X
# from sparse matrix to dense matrix
matrix = matrix.todense()
# find the most variable features (columns) of the matrix sorted by variance
variances = np.sort(-np.var(matrix, axis=0))
sorted_array = [np.log(-i) for i in variances.T][:2000]
# plot the variance of the features
plt.scatter([i for i in range(len(sorted_array))], sorted_array)
# Out:
# /var/folders/13/j6b4qnl1339416k0hpyswb8r0000gn/T/ipykernel_29357/521235833.py:6: RuntimeWarning: divide by zero encountered in log
#   sorted_array = [np.log(-i) for i in variances.T][:2000]

# %%
sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)

# %%
sc.pp.highly_variable_genes(adata, n_top_genes=2000, flavor='seurat_v3') # seurat FindVariableFeatures
# Out:
# /Users/paulmagos/miniconda3/envs/CHLPy/lib/python3.10/site-packages/scanpy/preprocessing/_highly_variable_genes.py:62: UserWarning: `flavor='seurat_v3'` expects raw count data, but non-integers were found.
#   warnings.warn(

# %%
sc.pl.highly_variable_genes(adata)

# %%
sc.pp.scale(adata, max_value=10)

# %%
sc.tl.pca(adata, svd_solver='arpack', n_comps=20, use_highly_variable=True)
sc.pl.pca_variance_ratio(adata, log=True)

# %%
sc.pp.neighbors(adata, n_neighbors=20, n_pcs=20)

res = 0.000
sc.tl.leiden(adata, resolution=res)
while not (adata.obs.leiden.values.categories.values).shape == (num_of_clusters, ) or res == 1.0:
    res += 0.005
    sc.tl.leiden(adata, resolution=res)
    
sc.pl.pca(adata, color=['leiden'], size=20)
# Out:
# /Users/paulmagos/miniconda3/envs/CHLPy/lib/python3.10/site-packages/umap/distances.py:1063: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /Users/paulmagos/miniconda3/envs/CHLPy/lib/python3.10/site-packages/umap/distances.py:1071: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /Users/paulmagos/miniconda3/envs/CHLPy/lib/python3.10/site-packages/umap/distances.py:1086: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /Users/paulmagos/miniconda3/envs/CHLPy/lib/python3.10/site-packages/umap/umap_.py:660: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# Iteration: 0, resolution: 0.0, clusters: (1,)
# Iteration: 0, resolution: 0.005, clusters: (3,)
# Iteration: 0, resolution: 0.01, clusters: (3,)
# Iteration: 0, resolution: 0.015, clusters: (3,)
# Iteration: 0, resolution: 0.02, clusters: (3,)
# Iteration: 0, resolution: 0.025, clusters: (4,)
# Iteration: 0, resolution: 0.030000000000000002, clusters: (4,)
# Iteration: 0, resolution: 0.035, clusters: (4,)
# Iteration: 0, resolution: 0.04, clusters: (4,)
# Iteration: 0, resolution: 0.045, clusters: (4,)
# Iteration: 0, resolution: 0.049999999999999996, clusters: (5,)
# Iteration: 0, resolution: 0.05499999999999999, clusters: (5,)
# Iteration: 0, resolution: 0.05999999999999999, clusters: (5,)
# Iteration: 0, resolution: 0.06499999999999999, clusters: (5,)
# Iteration: 0, resolution: 0.06999999999999999, clusters: (5,)
# Iteration: 0, resolution: 0.075, clusters: (5,)
# Iteration: 0, resolution: 0.08, clusters: (5,)
# Iteration: 0, resolution: 0.085, clusters: (5,)
# Iteration: 0, resolution: 0.09000000000000001, clusters: (5,)
# Iteration: 0, resolution: 0.09500000000000001, clusters: (5,)
# Iteration: 0, resolution: 0.10000000000000002, clusters: (5,)
# Iteration: 0, resolution: 0.10500000000000002, clusters: (5,)
# Iteration: 0, resolution: 0.11000000000000003, clusters: (5,)
# Iteration: 0, resolution: 0.11500000000000003, clusters: (6,)
# Iteration: 0, resolution: 0.12000000000000004, clusters: (6,)
# Iteration: 0, resolution: 0.12500000000000003, clusters: (6,)
# Iteration: 0, resolution: 0.13000000000000003, clusters: (5,)
# Iteration: 0, resolution: 0.13500000000000004, clusters: (5,)
# Iteration: 0, resolution: 0.14000000000000004, clusters: (5,)
# Iteration: 0, resolution: 0.14500000000000005, clusters: (6,)
# Iteration: 0, resolution: 0.15000000000000005, clusters: (6,)
# Iteration: 0, resolution: 0.15500000000000005, clusters: (6,)
# Iteration: 0, resolution: 0.16000000000000006, clusters: (6,)
# Iteration: 0, resolution: 0.16500000000000006, clusters: (6,)
# Iteration: 0, resolution: 0.17000000000000007, clusters: (6,)
# Iteration: 0, resolution: 0.17500000000000007, clusters: (6,)
# Iteration: 0, resolution: 0.18000000000000008, clusters: (6,)
# Iteration: 0, resolution: 0.18500000000000008, clusters: (6,)
# Iteration: 0, resolution: 0.19000000000000009, clusters: (6,)
# Iteration: 0, resolution: 0.1950000000000001, clusters: (6,)
# Iteration: 0, resolution: 0.2000000000000001, clusters: (6,)
# Iteration: 0, resolution: 0.2050000000000001, clusters: (6,)
# Iteration: 0, resolution: 0.2100000000000001, clusters: (6,)
# Iteration: 0, resolution: 0.2150000000000001, clusters: (6,)
# Iteration: 0, resolution: 0.2200000000000001, clusters: (6,)
# Iteration: 0, resolution: 0.22500000000000012, clusters: (6,)
# Iteration: 0, resolution: 0.23000000000000012, clusters: (6,)
# Iteration: 0, resolution: 0.23500000000000013, clusters: (6,)
# Iteration: 0, resolution: 0.24000000000000013, clusters: (6,)
# Iteration: 0, resolution: 0.24500000000000013, clusters: (7,)
# Iteration: 0, resolution: 0.2500000000000001, clusters: (7,)
# Iteration: 0, resolution: 0.2550000000000001, clusters: (7,)
# Iteration: 0, resolution: 0.2600000000000001, clusters: (6,)
# Iteration: 0, resolution: 0.2650000000000001, clusters: (7,)
# Iteration: 0, resolution: 0.27000000000000013, clusters: (8,)
# Iteration: 0, resolution: 0.27500000000000013, clusters: (8,)
# Iteration: 0, resolution: 0.28000000000000014, clusters: (8,)
# Iteration: 0, resolution: 0.28500000000000014, clusters: (8,)
# Iteration: 0, resolution: 0.29000000000000015, clusters: (8,)
# Iteration: 0, resolution: 0.29500000000000015, clusters: (8,)
# Iteration: 0, resolution: 0.30000000000000016, clusters: (8,)
# Iteration: 0, resolution: 0.30500000000000016, clusters: (8,)
# Iteration: 0, resolution: 0.31000000000000016, clusters: (8,)
# Iteration: 0, resolution: 0.31500000000000017, clusters: (8,)
# Iteration: 0, resolution: 0.3200000000000002, clusters: (8,)
# Iteration: 0, resolution: 0.3250000000000002, clusters: (8,)
# Iteration: 0, resolution: 0.3300000000000002, clusters: (8,)
# Iteration: 0, resolution: 0.3350000000000002, clusters: (8,)
# Iteration: 0, resolution: 0.3400000000000002, clusters: (9,)
# Iteration: 0, resolution: 0.3450000000000002, clusters: (9,)
# Iteration: 0, resolution: 0.3500000000000002, clusters: (9,)
# Iteration: 0, resolution: 0.3550000000000002, clusters: (9,)
# Iteration: 0, resolution: 0.3600000000000002, clusters: (9,)
# Iteration: 0, resolution: 0.3650000000000002, clusters: (9,)
# Iteration: 0, resolution: 0.3700000000000002, clusters: (9,)
# Iteration: 0, resolution: 0.3750000000000002, clusters: (9,)
# Iteration: 0, resolution: 0.3800000000000002, clusters: (9,)
# Iteration: 0, resolution: 0.38500000000000023, clusters: (9,)
# Iteration: 0, resolution: 0.39000000000000024, clusters: (9,)
# Iteration: 0, resolution: 0.39500000000000024, clusters: (9,)
# Iteration: 0, resolution: 0.40000000000000024, clusters: (9,)
# Iteration: 0, resolution: 0.40500000000000025, clusters: (10,)
# Iteration: 0, resolution: 0.41000000000000025, clusters: (10,)
# Iteration: 0, resolution: 0.41500000000000026, clusters: (10,)
# Iteration: 0, resolution: 0.42000000000000026, clusters: (10,)
# Iteration: 0, resolution: 0.42500000000000027, clusters: (10,)
# Iteration: 0, resolution: 0.43000000000000027, clusters: (10,)
# Iteration: 0, resolution: 0.4350000000000003, clusters: (9,)
# Iteration: 0, resolution: 0.4400000000000003, clusters: (9,)
# Iteration: 0, resolution: 0.4450000000000003, clusters: (9,)
# Iteration: 0, resolution: 0.4500000000000003, clusters: (9,)
# Iteration: 0, resolution: 0.4550000000000003, clusters: (9,)
# Iteration: 0, resolution: 0.4600000000000003, clusters: (9,)
# Iteration: 0, resolution: 0.4650000000000003, clusters: (9,)
# Iteration: 0, resolution: 0.4700000000000003, clusters: (9,)
# Iteration: 0, resolution: 0.4750000000000003, clusters: (10,)
# Iteration: 0, resolution: 0.4800000000000003, clusters: (10,)
# Iteration: 0, resolution: 0.4850000000000003, clusters: (9,)
# Iteration: 0, resolution: 0.4900000000000003, clusters: (9,)
# /Users/paulmagos/miniconda3/envs/CHLPy/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
# cluster id for each cell renamed as cluster

df = pd.DataFrame(adata.obs['leiden'])

labels = df.rename(columns={'leiden': 'cluster'})
labels.index.name = 'cell'

labels['cluster'] = labels['cluster'].astype(int) + 1

labels.to_csv(f'{save_path}/clustering_labels.csv', index=True)

# %%
sc.tl.rank_genes_groups(adata, 'leiden', method='wilcoxon')
# Out:
# /Users/paulmagos/miniconda3/envs/CHLPy/lib/python3.10/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /Users/paulmagos/miniconda3/envs/CHLPy/lib/python3.10/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /Users/paulmagos/miniconda3/envs/CHLPy/lib/python3.10/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /Users/paulmagos/miniconda3/envs/CHLPy/lib/python3.10/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /Users/paulmagos/miniconda3/envs/CHLPy/lib/python3.10/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /Users/paulmagos/miniconda3/envs/CHLPy/lib/python3.10/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /Users/paulmagos/miniconda3/envs/CHLPy/lib/python3.10/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /Users/paulmagos/miniconda3/envs/CHLPy/lib/python3.10/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /Users/paulmagos/miniconda3/envs/CHLPy/lib/python3.10/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /Users/paulmagos/miniconda3/envs/CHLPy/lib/python3.10/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /Users/paulmagos/miniconda3/envs/CHLPy/lib/python3.10/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(

# %%
number_of_genes = 50

names = adata.uns['rank_genes_groups']['names'][:number_of_genes]
# transform each element of names in a list
names = [list(x) for x in names]

df = pd.DataFrame(columns=['gene', 'cluster', 'rank'])

for i in range(num_of_clusters):
    to_add = [ [names[j][i], i, j] for j in range(number_of_genes)]
    to_add = pd.DataFrame(to_add, columns=['gene', 'cluster', 'rank'])
    df = pd.concat([df, to_add],  ignore_index=True)


df['cluster'] = df['cluster'].astype(int) + 1
df['rank'] = df['rank'].astype(int) + 1

df.to_csv(f'{save_path}/markers.csv', index=False)
